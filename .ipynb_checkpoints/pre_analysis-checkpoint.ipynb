# %% [markdown]
# # Heart Disease Data Analysis

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('../data/processed.data.csv')

df.head()
# Out:
#     age  sex   cp  trestbps   chol  fbs  restecg  thalach  exang  oldpeak  \
# 0  63.0  1.0  1.0     145.0  233.0  1.0      2.0    150.0    0.0      2.3
# 1  67.0  1.0  4.0     160.0  286.0  0.0      2.0    108.0    1.0      1.5
# 2  67.0  1.0  4.0     120.0  229.0  0.0      2.0    129.0    1.0      2.6
# 3  37.0  1.0  3.0     130.0  250.0  0.0      0.0    187.0    0.0      3.5
# 4  41.0  0.0  2.0     130.0  204.0  0.0      2.0    172.0    0.0      1.4
#
#    slope   ca  thal  target
# 0    3.0  0.0   6.0       0
# 1    2.0  3.0   3.0       2
# 2    2.0  2.0   7.0       1
# 3    3.0  0.0   3.0       0
# 4    1.0  0.0   3.0       0

# %% [markdown]
# ## Data Description
#
# •    age: The person's age in years
#
# •    sex: The person's sex (1 = male, 0 = female)
#
# •    cp: The chest pain experienced (Value 1: typical angina, Value 2: atypical angina, Value 3: non-anginal pain, Value 4: asymptomatic)
#
# •    trestbps: The person's resting blood pressure (mm Hg on admission to the hospital)
#
# •    chol: The person's cholesterol measurement in mg/dl
#
# •    fbs: The person's fasting blood sugar (> 120 mg/dl, 1 = true; 0 = false)
#
# •    restecg: Resting electrocardiographic measurement (0 = normal, 1 = having ST-T wave abnormality, 2 = showing probable or definite left ventricular hypertrophy by Estes' criteria)
#
# •    thalach: The person's maximum heart rate achieved
#
# •    exang: Exercise induced angina (1 = yes; 0 = no)
#
# •    oldpeak: ST depression induced by exercise relative to rest ('ST' relates to positions on the ECG plot. See more here)
#
# •    slope: the slope of the peak exercise ST segment (Value 1: upsloping, Value 2: flat, Value 3: downsloping)
#
# •    ca: The number of major vessels (0-3)
#
# •    thal: A blood disorder called thalassemia (3 = normal; 6 = fixed defect; 7 = reversable defect)
#
# •    target: Heart disease (0 = no, 1+ = yes)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 920 entries, 0 to 919
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       920 non-null    float64
#  1   sex       920 non-null    float64
#  2   cp        920 non-null    float64
#  3   trestbps  861 non-null    float64
#  4   chol      890 non-null    float64
#  5   fbs       830 non-null    float64
#  6   restecg   918 non-null    float64
#  7   thalach   865 non-null    float64
#  8   exang     865 non-null    float64
#  9   oldpeak   858 non-null    float64
#  10  slope     611 non-null    float64
#  11  ca        309 non-null    float64
#  12  thal      434 non-null    float64
#  13  target    920 non-null    int64
# dtypes: float64(13), int64(1)
# memory usage: 100.8 KB

# %% [markdown]
# ## Null Value Check

# %%
plt.figure(figsize=(20,10))
plt.xticks(size=20,color='grey')
plt.tick_params(size=12,color='grey')
plt.title('Null Value Heatmap',color='grey',size=30)
sns.heatmap(df.isnull(),
            yticklabels=False,
            cbar=False,
            cmap='PuBu_r',
            )
# Out:
# <AxesSubplot:title={'center':'Null Value Heatmap'}>

# %% [markdown]
# ## Correlation Matrix

# %%
plt.figure(figsize=(14,10))
sns.heatmap(df.corr(),annot=True,cmap="magma",fmt='.2f')

plt.show()

# %%
dfcount = df.copy()

def sexlbl(sex):
    if sex == 0:
        return 'female'
    else:
        return 'male'
    
def cadlbl(target):
    if target == 0:
        return 'No CAD'
    else:
        return 'CAD'
    
dfcount['sex'] = dfcount['sex'].apply(sexlbl)
dfcount['target'] = dfcount['target'].apply(cadlbl)

# %%
sns.countplot(x ='sex', hue = "target", data = dfcount)

plt.show()

# %% [markdown]
# ## Correlation 2
# CAD diagnosis (target) as binary instead of scaled

# %%
dfcorr = df.copy()

def cadbin(target):
    if target == 0:
        return 0
    else:
        return 1
    
dfcorr['target'] = dfcorr['target'].apply(cadbin)

plt.figure(figsize=(14,10))
sns.heatmap(dfcorr.corr(),annot=True,cmap="magma",fmt='.2f')

plt.show()

# %% [markdown]
# ### Removing vlaues with low correlation (in this case removing values inside +/-.2
# Leaving age, sex and slope to possibly be removed later depending on prediction success.

# %%
dfcorr = dfcorr.drop(columns=['trestbps','chol','fbs','restecg'])


plt.figure(figsize=(14,10))
sns.heatmap(dfcorr.corr(),annot=True,cmap="magma",fmt='.2f')

plt.show()

# %%
dfcorr.head()
# Out:
#     age  sex   cp  thalach  exang  oldpeak  slope   ca  thal  target
# 0  63.0  1.0  1.0    150.0    0.0      2.3    3.0  0.0   6.0       0
# 1  67.0  1.0  4.0    108.0    1.0      1.5    2.0  3.0   3.0       1
# 2  67.0  1.0  4.0    129.0    1.0      2.6    2.0  2.0   7.0       1
# 3  37.0  1.0  3.0    187.0    0.0      3.5    3.0  0.0   3.0       0
# 4  41.0  0.0  2.0    172.0    0.0      1.4    1.0  0.0   3.0       0
